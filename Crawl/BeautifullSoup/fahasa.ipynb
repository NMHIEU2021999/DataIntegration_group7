# %%
#!pip install --quiet bs4
from bs4 import BeautifulSoup 
import requests
import csv
import pandas as pd
from time import time

# %%
store = []

# %%
# %%time
for i in range(1,1000):
    print(i)
    try:
        stri = f'https://www.fahasa.com/all-category.html?order=num_orders&limit=24&p={i}'
        source = requests.get(stri, headers={
        "User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"
        }).text
        soup = BeautifulSoup(source, 'lxml')

        a = soup.find('ul', id='products_grid', class_='products-grid fhs-top')
        b = a.find_all('li')
        for i in b:
            try:
                url = str(i).split('href="')[1].split('" title')[0]
                source = requests.get(url, headers={
                "User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"
                }).text
                soup_1 = BeautifulSoup(source, 'lxml')

                image_url = str(soup_1.find('div', class_='product-view-image-product').img).split('data-src="')[1].split('" id="image"')[0]

                name = str(soup_1.find('div', class_='product-view-image-product').img).split('" class')[0].split('<img alt="')[1]

                tag_price = soup_1.find('div', class_='col-md-12 price-block').find('div', class_='price-box').find_all('p')
                if len(tag_price) == 2:
                    price = str(soup_1.find('div', class_='col-md-12 price-block').find('div', class_='price-box').find_all('p')[1].find_all('span')[1]).split('\xa0')[0].split('>')[1]
                if len(tag_price) == 1:
                    price = str(soup_1.find('div', class_='col-md-12 price-block').find('div', class_='price-box').find_all('p')[0].find_all('span')[1]).split('\xa0')[0].split('>')[1]

                len_author = len(str(soup_1.find_all('table', class_='data-table table-additional')).split('class="data_author">\n\t\t\t\t    '))
                if len_author == 1:
                    author_name = 'NULL'
                if len_author > 1:
                    author_name = str(soup_1.find_all('table', class_='data-table table-additional')).split('class="data_author">\n\t\t\t\t    ')[1].split('\t')[0]

                provider = str(soup_1.find_all('table', class_='data-table table-additional')).split('ATTRIBUTE_PRODUCT">')[2].split('<')[0]
                publisher = str(soup_1.find_all('table', class_='data-table table-additional')).split('publisher">\n\t\t\t\t    ')[1].split('\t')[0]
                num_page = str(soup_1.find_all('table', class_='data-table table-additional')).split('class="data_qty_of_page">\n\t\t\t\t    ')[1].split('\t')[0]
                cover_type = str(soup_1.find_all('table', class_='data-table table-additional')).split('class="data_book_layout">\n\t\t\t\t    ')[1].split('\t')[0]
                size = str(soup_1.find_all('table', class_='data-table table-additional')).split('data_size">\n\t\t\t\t    ')[1].split('\t')[0]
                release_year = str(soup_1.find_all('table', class_='data-table table-additional')).split('class="data_publish_year">\n\t\t\t\t    ')[1].split('\t')[0]
                store.append((url, image_url, name, author_name, price, provider, publisher, num_page, cover_type, size, release_year))
            except:
                continue
    except:
        continue
# Out:
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# 431
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# 441
# 442
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
# 480
# 481
# 482
# 483
# 484
# 485
# 486
# 487
# 488
# 489
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# 501
# 502
# 503
# 504
# 505
# 506
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
# 520
# 521
# 522
# 523
# 524
# 525
# 526
# 527
# 528
# 529
# 530
# 531
# 532
# 533
# 534
# 535
# 536
# 537
# 538
# 539
# 540
# 541
# 542
# 543
# 544
# 545
# 546
# 547
# 548
# 549
# 550
# 551
# 552
# 553
# 554
# 555
# 556
# 557
# 558
# 559
# 560
# 561
# 562
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# 570
# 571
# 572
# 573
# 574
# 575
# 576
# 577
# 578
# 579
# 580
# 581
# 582
# 583
# 584
# 585
# 586
# 587
# 588
# 589
# 590
# 591
# 592
# 593
# 594
# 595
# 596
# 597
# 598
# 599
# 600
# 601
# 602
# 603
# 604
# 605
# 606
# 607
# 608
# 609
# 610
# 611
# 612
# 613
# 614
# 615
# 616
# 617
# 618
# 619
# 620
# 621
# 622
# 623
# 624
# 625
# 626
# 627
# 628
# 629
# 630
# 631
# 632
# 633
# 634
# 635
# 636
# 637
# 638
# 639
# 640
# 641
# 642
# 643
# 644
# 645
# 646
# 647
# 648
# 649
# 650
# 651
# 652
# 653
# 654
# 655
# 656
# 657
# 658
# 659
# 660
# 661
# 662
# 663
# 664
# 665
# 666
# 667
# 668
# 669
# 670
# 671
# 672
# 673
# 674
# 675
# 676
# 677
# 678
# 679
# 680
# 681
# 682
# 683
# 684
# 685
# 686
# 687
# 688
# 689
# 690
# 691
# 692
# 693
# 694
# 695
# 696
# 697
# 698
# 699
# Wall time: 3h 9min 49s

# %%
column_name = ['url', 'image_url', 'author_name', 'name', 'price', 'provider', 'publisher', 'num_page', 'cover_type', 'size', 'release_year']
df = pd.DataFrame.from_records(store, columns=column_name)
df
# Out:
#                                                     url  \
# 0     https://www.fahasa.com/cau-chuyen-dong-song-ng...
# 1     https://www.fahasa.com/hoc-tot-dia-li-7-271919...
# 2     https://www.fahasa.com/trac-nghiem-chuyen-de-g...
# 3     https://www.fahasa.com/pokemon-dac-biet-tap-11...
# 4     https://www.fahasa.com/pokemon-dac-biet-tap-12...
# ...                                                 ...
# 1194  https://www.fahasa.com/tong-on-tap-hoa-vo-co-3...
# 1195  https://www.fahasa.com/luyen-chuyen-sau-ngu-ph...
# 1196      https://www.fahasa.com/ot-bay-mau-tap-03.html
# 1197  https://www.fahasa.com/the-langmaster-chinh-ph...
# 1198  https://www.fahasa.com/ehon-mot-sach-mogu-che-...
#
#                                               image_url  \
# 0     https://cdn0.fahasa.com/media/catalog/product/...
# 1     https://cdn0.fahasa.com/media/catalog/product/...
# 2     https://cdn0.fahasa.com/media/catalog/product/...
# 3     https://cdn0.fahasa.com/media/catalog/product/...
# 4     https://cdn0.fahasa.com/media/catalog/product/...
# ...                                                 ...
# 1194  https://cdn0.fahasa.com/media/catalog/product/...
# 1195  https://cdn0.fahasa.com/media/catalog/product/...
# 1196  https://cdn0.fahasa.com/media/catalog/product/...
# 1197  https://cdn0.fahasa.com/media/catalog/product/...
# 1198  https://cdn0.fahasa.com/media/catalog/product/...
#
#                                             author_name  \
# 0             Câu Chuyện Dòng Sông - Người Mẹ Sông Hồng
# 1                                      Học Tốt Địa Lí 7
# 2        Trắc Nghiệm Chuyên Đề Giải Tích Và Hình Học 12
# 3              Pokémon Đặc Biệt - Tập 11 (Tái Bản 2020)
# 4              Pokémon Đặc Biệt - Tập 12 (Tái Bản 2020)
# ...                                                 ...
# 1194                              Tổng Ôn Tập Hóa Vô Cơ
# 1195  Luyện Chuyên Sâu Ngữ Pháp Và Từ Vựng Tiếng Anh...
# 1196                                Ớt Bảy Màu - Tập 03
# 1197  The Langmaster - Chinh Phục Ngữ Pháp Và Bài Tậ...
# 1198  Ehon - Mọt Sách Mogu - Che Ô Cho Bạn Nhé (Từ 0...
#
#                                                    name    price  \
# 0              Thủy Nguyên, Yến Ngọc, Ru Oi, Tuấn Thanh   65.000
# 1                                     NGUT Tăng Văn Dom   49.000
# 2                                         Nhiều Tác Giả  290.000
# 3                     Hidenori Kusaka, Satoshi Yamamoto   25.000
# 4                     Hidenori Kusaka, Satoshi Yamamoto   25.000
# ...                                                 ...      ...
# 1194  Nguyễn Hoàng Vũ, Nguyễn Viết Long, Đỗ Bách Kho...  220.000
# 1195                                   Đại Lợi, Vân Anh   75.000
# 1196                                     Mitsuru Adachi   65.000
# 1197                                 Nguyễn Thị Thu Huế   72.000
# 1198                 Setsuko Hasegawa, Kayako Nishimaki   32.000
#
#                               provider                    publisher num_page  \
# 0                Nhà Xuất Bản Kim Đồng                 NXB Kim Đồng       44
# 1                                Cấp 2                NXB Thanh Hóa      158
# 2                                Cấp 3  NXB Đại Học Quốc Gia Hà Nội      748
# 3                            Adventure                 NXB Kim Đồng      204
# 4                            Adventure                 NXB Kim Đồng      204
# ...                                ...                          ...      ...
# 1194                             Cấp 3                  NXB Đà Nẵng      570
# 1195                             Cấp 1  NXB Đại Học Quốc Gia Hà Nội      144
# 1196                         Adventure                      NXB Trẻ      347
# 1197                             Cấp 2  NXB Đại Học Quốc Gia Hà Nội      164
# 1198  Cty TNHH More Production Vietnam                 NXB Kim Đồng       20
#
#      cover_type              size release_year
# 0       Bìa Mềm  29 x 20 x 0.3 cm         2019
# 1       Bìa Mềm        16 x 24 cm         2019
# 2       Bìa Mềm        19 x 27 cm         2019
# 3       Bìa Mềm    12.5 x 17.6 cm         2020
# 4       Bìa Mềm    12.5 x 17.6 cm         2020
# ...         ...               ...          ...
# 1194    Bìa Mềm        27 x 19 cm         2020
# 1195    Bìa Mềm  27 x 19 x 0.6 cm         2021
# 1196    Bìa Mềm  19 x 13 x 2.5 cm         2021
# 1197    Bìa Mềm        24 x 17 cm         2021
# 1198    Bìa Mềm  20 x 20 x 0.5 cm         2020
#
# [1199 rows x 11 columns]

# %%
df.to_csv('fahasa.csv')
